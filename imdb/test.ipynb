# %%
import pandas as pd

# %%
df = pd.read_csv('resultats.csv')

# %%
df.head()
# Out:
#        annee_pegi_duree                                  casting_principal  \
# 0         1994,R,2h 22m  Tim Robbins,Morgan Freeman,Bob Gunton,William ...
# 1         1972,R,2h 55m  Marlon Brando,Al Pacino,James Caan,Diane Keato...
# 2     2008,PG-13,2h 32m  Christian Bale,Heath Ledger,Aaron Eckhart,Mich...
# 3         1974,R,3h 22m  Al Pacino,Robert De Niro,Robert Duvall,Diane K...
# 4  1957,Approved,1h 36m  Henry Fonda,Lee J. Cobb,Martin Balsam,John Fie...
#
#                                          description               genre  \
# 0  Over the course of several years, two convicts...               Drama
# 1  The aging patriarch of an organized crime dyna...         Crime,Drama
# 2  When the menace known as the Joker wreaks havo...  Action,Crime,Drama
# 3  The early life and career of Vito Corleone in ...         Crime,Drama
# 4  The jury in a New York City murder trial is fr...         Crime,Drama
#
#                                    langue nombre_vote  \
# ...
